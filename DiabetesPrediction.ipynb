# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
print(sklearn.__version__)
# Out:
# 1.6.0

# %%
pip install scikit-learn==1.6.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached scikit_learn-1.6.0-cp312-cp312-win_amd64.whl.metadata (15 kB)
# ...
# Using cached scikit_learn-1.6.0-cp312-cp312-win_amd64.whl (11.1 MB)
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.5.1
#     Uninstalling scikit-learn-1.5.1:
#       Successfully uninstalled scikit-learn-1.5.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
print(sklearn.__version__)
# Out:
# 1.6.0

# %%
diabetes_dataset=pd.read_csv('diabetes.csv')
diabetes_dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_dataset['Glucose']=np.where(diabetes_dataset['Glucose']==0,diabetes_dataset['Glucose'].median(),diabetes_dataset['Glucose'])
diabetes_dataset['Insulin']=np.where(diabetes_dataset['Insulin']==0,diabetes_dataset['Insulin'].median(),diabetes_dataset['Insulin'])
diabetes_dataset['SkinThickness']=np.where(diabetes_dataset['SkinThickness']==0,diabetes_dataset['SkinThickness'].median(),diabetes_dataset['SkinThickness'])
diabetes_dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0             72           35.0     30.5  33.6
# 1            1     85.0             66           29.0     30.5  26.6
# 2            8    183.0             64           23.0     30.5  23.3
# 3            1     89.0             66           23.0     94.0  28.1
# 4            0    137.0             40           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_dataset.shape
# Out:
# (768, 9)

# %%
diabetes_dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.656250      69.105469      27.334635   94.652344
# std       3.369578   30.438286      19.355807       9.229014  105.547598
# min       0.000000   44.000000       0.000000       7.000000   14.000000
# 25%       1.000000   99.750000      62.000000      23.000000   30.500000
# 50%       3.000000  117.000000      72.000000      23.000000   31.250000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
 diabetes_dataset['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
diabetes_dataset.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  110.682000      68.184000      26.058000   83.188000
# 1           4.865672  142.130597      70.824627      29.716418  116.041045
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
X = diabetes_dataset.drop(columns = 'Outcome', axis=1)
Y = diabetes_dataset['Outcome']

# %%
print(X)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0             72           35.0     30.5  33.6
# 1              1     85.0             66           29.0     30.5  26.6
# 2              8    183.0             64           23.0     30.5  23.3
# 3              1     89.0             66           23.0     94.0  28.1
# 4              0    137.0             40           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0             76           48.0    180.0  32.9
# 764            2    122.0             70           27.0     30.5  36.8
# 765            5    121.0             72           23.0    112.0  26.2
# 766            1    126.0             60           23.0     30.5  30.1
# 767            1     93.0             70           31.0     30.5  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
print(Y)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
scaler = StandardScaler()
scaler.fit(X)
standardized_data = scaler.transform(X)

# %%
print(standardized_data)
# Out:
# [[ 0.63994726  0.86604475  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.20506583 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  2.01666174 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808  -0.02157407  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.14279979 -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.94206766  0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
X = standardized_data
Y = diabetes_dataset['Outcome']
print(X)
# Out:
# [[ 0.63994726  0.86604475  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.20506583 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  2.01666174 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808  -0.02157407  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.14279979 -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.94206766  0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %% [markdown]
# # Training the Model

# %%
classifier = svm.SVC(kernel='linear')

# %%
#training the support vector Machine Classifier
classifier.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %%
# accuracy score on the training data
X_train_prediction = classifier.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy score of the training data : ', training_data_accuracy)
# Out:
# Accuracy score of the training data :  0.7882736156351792

# %%
# accuracy score on the test data
X_test_prediction = classifier.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score of the test data : ', test_data_accuracy)
# Out:
# Accuracy score of the test data :  0.7727272727272727

# %% [markdown]
# # Predictive System

# %%
input_data= (5,165,72,20,175,27.8,0.587,51)

# changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

# standardize the input data
std_data = scaler.transform(input_data_reshaped)
print(std_data)

prediction = classifier.predict(std_data)
print(prediction)
# Out:
# [[ 0.3429808   1.42491586  0.14964075 -0.79525451  0.76174179 -0.53211885
#    0.34768723  1.51108316]]
# [1]
# C:\Users\khush\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
if (prediction[0] == 0):
  print('The person is not diabetic')
else:
  print('The person is diabetic')
# Out:
# The person is diabetic

# %%
import pickle

# %%
pickle.dump(classifier,open('diabetes_model.pkl','wb'))

# %%
pickle.dump(scaler,open('diabetes_model1.pkl','wb'))
